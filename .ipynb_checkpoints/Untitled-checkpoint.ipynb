# %%
import torch
from torch import nn,optim
from torch.autograd import Variable
from torch.nn import init
from matplotlib import pyplot as plot
import pandas as pd
import numpy as np

# %%
csvfile = pd.read_csv("../steering.csv")

# %%
print(csvfile.head(10))
# Out:
#              timestamp     angle  torque      speed
# 0  1479424214787219361  0.003491  0.1250  22.880556
# 1  1479424214807231859  0.003491  0.1250  22.886110
# 2  1479424214827300730  0.003491  0.1250  22.891666
# 3  1479424214847355643  0.003491  0.1875  22.897223
# 4  1479424214867355824  0.003491  0.0000  22.902779
# 5  1479424214887364135  0.003491  0.0625  22.905556
# 6  1479424214907399816  0.003491  0.2500  22.908333
# 7  1479424214927455132  0.003491 -0.0625  22.911112
# 8  1479424214947476806  0.001745  0.0000  22.913889
# 9  1479424214967638631  0.001745 -0.0625  22.913889

# %%
plot.figure(figsize=(30,16))
plot.plot(csvfile.timestamp, csvfile.angle,label='angle')
plot.xlabel("time")
plot.plot(csvfile.timestamp, csvfile.torque,label="torque")
plot.plot(csvfile.timestamp, csvfile.speed, label='speed')
plot.legend()

# %%
angle = csvfile.angle
torque = csvfile.torque
speed = csvfile.speed

# %%
print(csvfile.timestamp[200]-csvfile.timestamp[150])
# Out:
# 1001852483

# %%
timestamp = pd.to_datetime(csvfile.timestamp)

# %%
print(timestamp[0],timestamp[50])
# Out:
# 2016-11-17 23:10:14.787219361 2016-11-17 23:10:15.788910794

# %%
data = np.vstack((angle, torque, speed)).T

# %%
data.shape
# Out:
# (97887, 3)

# %%
train_data = data[0:len(data)-1]
train_label = data[1:len(data)]

# %%
class rnnModel(nn.Module):
    def __init__(self,in_dim,hidden_dim,out_dim,layer_num):
        super().__init__()
        self.rnnLayer=nn.RNN(in_dim,hidden_dim,layer_num)
        self.fcLayer=nn.Linear(hidden_dim,out_dim)
        optim_range=np.sqrt(1.0/hidden_dim)
        self.weightInit(optim_range)

    def forward(self, x):
        out,_=self.rnnLayer(x)
        out=self.fcLayer(out)
        return  out

    def weightInit(self,gain=1):
        for name ,param in self.named_parameters():
            if 'rnnLayer.weight' in name:
                init.orthogonal(param,gain)

# %%
len(train_data)
# Out:
# 97886

# %% [markdown]
# ## One sample

# %%
rnn_one=rnnModel(3,10,3,2)
criterion_one=nn.MSELoss()
optimizer_one=optim.Adam(rnn_one.parameters(),lr=1e-2)
sec = 200
initial_data = torch.from_numpy(train_data[0].astype(np.float32)).reshape(1,1,3)
for e in range(0, len(train_data)) :
    inputs = Variable(initial_data)
    target = Variable(torch.from_numpy(train_label[e].astype(np.float32)).reshape(1,1,3))
    # forward
    output = rnn_one(inputs)
    loss = criterion_one(output, target)
    # update gradients
    optimizer_one.zero_grad()
    loss.backward()
    optimizer_one.step()
    # print training information
    print_loss = loss.item()
    if e % sec == 0 :
        print('Epoch[{}/{}], predict data is {:.5f} {:.5f} {:.5f}, groud truth is {:.5f} {:.5f} {:.5f} loss = {:.10f}'.format(e,len(train_data),output.detach().numpy()[0,0,0],output.detach().numpy()[0,0,1],output.detach().numpy()[0,0,2],train_label[e,0],train_label[e,1],train_label[e,2], print_loss))
    initial_data = output
# Out:
# Epoch[0/97886], predict data is -0.35049 -0.25210 -0.23192, groud truth is 0.00349 0.12500 22.88611 loss = 178.2368927002
# C:\Users\ZG5\AppData\Local\Temp\ipykernel_10940\843651359.py:17: UserWarning: nn.init.orthogonal is now deprecated in favor of nn.init.orthogonal_.
#   init.orthogonal(param,gain)
# Epoch[200/97886], predict data is 0.00579 -0.34085 18.35050, groud truth is 0.01745 0.50000 23.07500 loss = 7.6760196686
# Epoch[400/97886], predict data is -0.00612 -0.28516 22.85260, groud truth is 0.00175 -0.31250 23.26944 loss = 0.0581897497
# Epoch[600/97886], predict data is 0.11395 0.73574 22.57562, groud truth is 0.11170 0.43750 22.45278 loss = 0.0346812941
# Epoch[800/97886], predict data is 0.07935 -0.19231 22.05468, groud truth is 0.09250 0.81250 21.85833 loss = 0.3494578898
# Epoch[1000/97886], predict data is 0.09106 0.34463 20.89404, groud truth is 0.09250 0.25000 20.92778 loss = 0.0033653323
# Epoch[1200/97886], predict data is 0.10275 0.01622 20.46981, groud truth is 0.10472 0.18750 20.48056 loss = 0.0098190960
# Epoch[1400/97886], predict data is 0.09148 0.06206 20.27968, groud truth is 0.09076 0.18750 20.25833 loss = 0.0053972919
# Epoch[1600/97886], predict data is 0.09262 0.15716 20.27689, groud truth is 0.09250 0.12500 20.36667 loss = 0.0030312950
# Epoch[1800/97886], predict data is -0.00223 -0.11952 21.07083, groud truth is -0.00349 0.00000 21.23056 loss = 0.0132665625
# Epoch[2000/97886], predict data is 0.00566 0.16153 22.45453, groud truth is 0.00524 0.50000 22.55278 loss = 0.0414054580
# Epoch[2200/97886], predict data is -0.01302 0.18944 22.73556, groud truth is -0.01047 0.00000 22.77222 loss = 0.0124129420
# Epoch[2400/97886], predict data is -0.06391 -0.64933 22.53778, groud truth is -0.06807 -0.81250 22.55278 loss = 0.0089560049
# Epoch[2600/97886], predict data is -0.02720 0.07738 22.17755, groud truth is -0.03142 -0.06250 21.89444 loss = 0.0332454257
# Epoch[2800/97886], predict data is -0.05672 -0.70376 20.88431, groud truth is -0.05934 -0.43750 20.96389 loss = 0.0257440526
# Epoch[3000/97886], predict data is -0.07087 -1.03239 22.07721, groud truth is -0.07156 -1.06250 22.10278 loss = 0.0005203494
# Epoch[3200/97886], predict data is -0.02150 0.28959 21.84887, groud truth is -0.02443 0.31250 21.68611 loss = 0.0090081329
# Epoch[3400/97886], predict data is -0.03825 -0.17569 19.81800, groud truth is -0.04014 0.00000 19.86389 loss = 0.0109919654
# Epoch[3600/97886], predict data is 0.00172 0.40358 20.88809, groud truth is 0.00175 0.12500 20.88889 loss = 0.0258682352
# Epoch[3800/97886], predict data is -0.01047 0.19882 22.10006, groud truth is -0.01047 0.12500 22.05556 loss = 0.0024765122
# Epoch[4000/97886], predict data is 0.00414 0.19462 22.13038, groud truth is 0.00349 -0.37500 22.11667 loss = 0.1082184017
# Epoch[4200/97886], predict data is 0.00764 -0.07363 21.58018, groud truth is 0.00524 0.06250 21.52500 loss = 0.0071944334
# Epoch[4400/97886], predict data is 0.01139 0.49425 21.54472, groud truth is 0.01396 0.37500 21.58889 loss = 0.0053927577
# Epoch[4600/97886], predict data is 0.00658 0.25590 23.66508, groud truth is 0.00698 0.31250 23.74444 loss = 0.0031673771
# Epoch[4800/97886], predict data is 0.01329 0.31411 25.20649, groud truth is 0.01396 0.50000 25.20555 loss = 0.0115192281
# Epoch[5000/97886], predict data is 0.00084 0.09593 25.15976, groud truth is 0.00175 0.18750 25.18333 loss = 0.0029807363
# Epoch[5200/97886], predict data is -0.01693 0.15266 25.66463, groud truth is -0.01222 -0.12500 25.68333 loss = 0.0258218106
# Epoch[5400/97886], predict data is 0.07957 0.27578 26.13182, groud truth is 0.07854 0.12500 26.12500 loss = 0.0075942501
# Epoch[5600/97886], predict data is 0.05868 -0.12397 25.66664, groud truth is 0.05411 -0.18750 25.65000 loss = 0.0014447217
# Epoch[5800/97886], predict data is 0.07888 0.12792 24.82561, groud truth is 0.07156 0.06250 24.79445 loss = 0.0017684553
# Epoch[6000/97886], predict data is 0.09756 0.69658 24.50923, groud truth is 0.10123 1.00000 24.52222 loss = 0.0307483301
# Epoch[6200/97886], predict data is 0.08293 0.49930 26.17289, groud truth is 0.08203 0.68750 26.18889 loss = 0.0118923364
# Epoch[6400/97886], predict data is 0.07764 0.70256 27.28573, groud truth is 0.07505 0.56250 27.30000 loss = 0.0066088829
# Epoch[6600/97886], predict data is 0.01059 0.36682 27.49798, groud truth is 0.00873 0.37500 27.51389 loss = 0.0001077705
# Epoch[6800/97886], predict data is -0.01620 -0.32305 26.83228, groud truth is -0.01571 0.18750 26.81111 loss = 0.0870372579
# Epoch[7000/97886], predict data is -0.00678 -0.22154 25.37577, groud truth is -0.01047 -0.31250 25.37778 loss = 0.0027640609
# Epoch[7200/97886], predict data is -0.11964 -1.04936 25.11104, groud truth is -0.11868 -0.81250 25.11944 loss = 0.0187248159
# Epoch[7400/97886], predict data is -0.15975 -1.25522 24.06479, groud truth is -0.15533 -0.81250 24.05278 loss = 0.0653869882
# Epoch[7600/97886], predict data is -0.10307 -0.53069 24.16044, groud truth is -0.10647 -0.43750 24.17222 loss = 0.0029448585
# Epoch[7800/97886], predict data is -0.12968 -1.14788 23.52019, groud truth is -0.13265 -0.93750 23.51944 loss = 0.0147556821
# Epoch[8000/97886], predict data is -0.12382 -0.92693 23.95160, groud truth is -0.12217 -1.12500 23.94444 loss = 0.0130953491
# Epoch[8200/97886], predict data is -0.12856 -0.83495 24.10805, groud truth is -0.12392 -0.62500 24.12222 loss = 0.0147668906
# Epoch[8400/97886], predict data is -0.05930 0.05564 25.37369, groud truth is -0.04712 0.00000 25.36389 loss = 0.0011132342
# Epoch[8600/97886], predict data is 0.00867 0.32942 25.86547, groud truth is 0.01396 0.37500 25.87778 loss = 0.0007522034
# Epoch[8800/97886], predict data is -0.02076 -0.61076 27.15847, groud truth is -0.02269 0.00000 27.15833 loss = 0.1243443862
# Epoch[9000/97886], predict data is 0.00149 0.22555 28.15055, groud truth is 0.00524 0.37500 28.15278 loss = 0.0074515273
# Epoch[9200/97886], predict data is 0.00108 0.18316 30.01450, groud truth is 0.00175 0.06250 30.00000 loss = 0.0049231779
# Epoch[9400/97886], predict data is -0.12108 -1.16151 30.16510, groud truth is -0.12566 -1.37500 30.16389 loss = 0.0151994517
# Epoch[9600/97886], predict data is -0.13314 -1.21587 28.79795, groud truth is -0.13265 -1.12500 28.78056 loss = 0.0028531577
# Epoch[9800/97886], predict data is -0.12111 -1.08150 26.84497, groud truth is -0.11345 -0.93750 26.83611 loss = 0.0069578742
# Epoch[10000/97886], predict data is -0.09067 -0.81310 25.76718, groud truth is -0.08901 -0.87500 25.76944 loss = 0.0012800294
# Epoch[10200/97886], predict data is -0.10426 -0.67188 23.86720, groud truth is -0.10123 -0.62500 23.88056 loss = 0.0007951978
# Epoch[10400/97886], predict data is -0.03919 0.17589 22.33311, groud truth is -0.04363 0.43750 22.33055 loss = 0.0228216443
# Epoch[10600/97886], predict data is -0.15987 -0.67977 22.29044, groud truth is -0.16581 -1.25000 22.28056 loss = 0.1084333360
# Epoch[10800/97886], predict data is -0.15909 -0.86814 20.40001, groud truth is -0.15359 -1.25000 20.37500 loss = 0.0488250740
# Epoch[11000/97886], predict data is -0.26162 -1.43361 20.00973, groud truth is -0.26878 -1.56250 20.00000 loss = 0.0055865892
# Epoch[11200/97886], predict data is -0.25080 -1.79570 19.81239, groud truth is -0.25307 -0.93750 19.82500 loss = 0.2455563396
# Epoch[11400/97886], predict data is -0.21985 -1.14325 17.84910, groud truth is -0.21642 -1.06250 17.84444 loss = 0.0021846169
# Epoch[11600/97886], predict data is 0.39842 1.44215 18.27848, groud truth is 0.39095 1.12500 18.23611 loss = 0.0341456942
# Epoch[11800/97886], predict data is 0.23852 0.77973 19.62757, groud truth is 0.24086 1.06250 19.63333 loss = 0.0266650002
# Epoch[12000/97886], predict data is 0.03789 0.76851 21.33375, groud truth is 0.04014 0.43750 21.33889 loss = 0.0365322940
# Epoch[12200/97886], predict data is 0.03611 0.97204 21.96346, groud truth is 0.03840 0.56250 22.01667 loss = 0.0568532348
# Epoch[12400/97886], predict data is 0.33410 1.34997 19.31751, groud truth is 0.32638 1.18750 19.34167 loss = 0.0090137040
# Epoch[12600/97886], predict data is 0.34757 1.52414 18.83472, groud truth is 0.35081 1.81250 18.85833 loss = 0.0279070493
# Epoch[12800/97886], predict data is 0.04175 -0.04645 18.59660, groud truth is 0.04363 0.37500 18.56944 loss = 0.0594533980
# Epoch[13000/97886], predict data is 0.24938 0.91258 18.39765, groud truth is 0.25482 1.06250 18.41945 loss = 0.0076598041
# Epoch[13200/97886], predict data is 0.29420 1.49890 20.97797, groud truth is 0.28972 1.37500 20.97778 loss = 0.0051240474
# Epoch[13400/97886], predict data is -0.03867 -0.39103 20.44365, groud truth is -0.03142 -0.31250 20.43889 loss = 0.0020805493
# Epoch[13600/97886], predict data is -0.20468 -1.50247 17.42348, groud truth is -0.20595 -1.75000 17.35556 loss = 0.0219622832
# Epoch[13800/97886], predict data is -0.12680 -0.33172 15.56294, groud truth is -0.12741 -0.12500 15.57500 loss = 0.0142923966
# Epoch[14000/97886], predict data is 0.00109 -0.57506 15.42547, groud truth is 0.00175 0.18750 15.46944 loss = 0.1944754720
# Epoch[14200/97886], predict data is 0.04101 0.24151 14.35509, groud truth is 0.04014 0.43750 14.35556 loss = 0.0128046377
# Epoch[14400/97886], predict data is 0.12129 0.66863 11.94818, groud truth is 0.12392 0.37500 11.94722 loss = 0.0287424382
# Epoch[14600/97886], predict data is -0.36184 -1.37704 10.91934, groud truth is -0.36652 -1.43750 10.96944 loss = 0.0020626283
# Epoch[14800/97886], predict data is -0.51174 -0.78000 10.87868, groud truth is -0.51313 -0.75000 10.87778 loss = 0.0003009246
# Epoch[15000/97886], predict data is -0.47437 -1.09144 12.41914, groud truth is -0.46600 -1.18750 12.49167 loss = 0.0048529166
# Epoch[15200/97886], predict data is -0.03678 0.26427 14.68599, groud truth is -0.03491 -0.18750 14.67778 loss = 0.0680545345
# Epoch[15400/97886], predict data is 0.39310 1.34247 14.80754, groud truth is 0.39794 1.62500 14.83333 loss = 0.0268365685
# Epoch[15600/97886], predict data is 0.05914 0.58203 16.21412, groud truth is 0.05585 0.00000 16.21667 loss = 0.1129240692
# Epoch[15800/97886], predict data is 0.24088 1.18355 15.54057, groud truth is 0.24958 1.12500 15.51111 loss = 0.0014573205
# Epoch[16000/97886], predict data is 0.28575 0.92653 14.95567, groud truth is 0.27925 1.25000 15.00000 loss = 0.0355476737
# Epoch[16200/97886], predict data is 0.29161 0.98698 16.23141, groud truth is 0.29322 1.37500 16.24722 loss = 0.0502702147
# Epoch[16400/97886], predict data is 0.08364 0.75626 19.13930, groud truth is 0.08901 0.87500 19.14722 loss = 0.0047303247
# Epoch[16600/97886], predict data is 0.10518 0.51516 19.47399, groud truth is 0.09774 0.00000 19.46944 loss = 0.0884871408
# Epoch[16800/97886], predict data is 0.03074 0.28058 19.07130, groud truth is 0.03316 0.25000 19.08889 loss = 0.0004167241
# Epoch[17000/97886], predict data is 0.02092 0.33909 18.93418, groud truth is 0.02094 0.37500 18.91667 loss = 0.0005320313
# Epoch[17200/97886], predict data is 0.20053 0.71155 17.03362, groud truth is 0.20246 0.62500 17.06944 loss = 0.0029258355
# Epoch[17400/97886], predict data is 0.00227 -0.17646 16.93693, groud truth is 0.00698 -0.06250 16.93333 loss = 0.0043403651
# Epoch[17600/97886], predict data is -0.01782 -0.56144 16.44352, groud truth is -0.01920 -0.50000 16.42778 loss = 0.0013414500
# Epoch[17800/97886], predict data is 0.04481 0.50832 15.33982, groud truth is 0.03840 0.12500 15.35556 loss = 0.0490739830
# Epoch[18000/97886], predict data is 0.16993 0.77518 15.69755, groud truth is 0.17104 0.62500 15.71111 loss = 0.0075801578
# Epoch[18200/97886], predict data is -0.05478 -0.41756 14.66552, groud truth is -0.05236 -0.75000 14.76111 loss = 0.0398855843
# Epoch[18400/97886], predict data is -1.11363 -2.57850 13.20272, groud truth is -1.12399 -2.62500 13.23611 loss = 0.0011279740
# Epoch[18600/97886], predict data is -0.91994 -0.70573 10.08269, groud truth is -0.92677 -2.00000 10.02500 loss = 0.5594996810
# Epoch[18800/97886], predict data is -0.63830 -1.24583 11.45915, groud truth is -0.63705 -0.87500 11.43333 loss = 0.0460599512
# Epoch[19000/97886], predict data is 0.41265 1.09508 12.47741, groud truth is 0.40492 1.31250 12.47778 loss = 0.0157775450
# Epoch[19200/97886], predict data is -0.07095 -0.76774 13.50018, groud truth is -0.07679 -0.81250 13.51111 loss = 0.0007190479
# Epoch[19400/97886], predict data is -0.00722 -0.27963 12.61869, groud truth is -0.00175 -0.37500 12.64722 loss = 0.0033128711
# Epoch[19600/97886], predict data is 0.55345 1.07128 9.67079, groud truth is 0.52185 1.12500 9.34444 loss = 0.0367963947
# Epoch[19800/97886], predict data is 0.94695 0.84744 9.12301, groud truth is 0.95470 1.43750 9.12778 loss = 0.1160836220
# Epoch[20000/97886], predict data is 0.54824 0.80254 10.93134, groud truth is 0.54629 0.25000 10.91389 loss = 0.1018705443
# Epoch[20200/97886], predict data is -0.01149 0.12124 13.15018, groud truth is -0.01047 -0.25000 13.15278 loss = 0.0459425710
# Epoch[20400/97886], predict data is -0.48490 -1.44568 12.62894, groud truth is -0.48869 -1.31250 12.60833 loss = 0.0060589202
# Epoch[20600/97886], predict data is -0.13817 0.74363 9.32262, groud truth is -0.14312 0.56250 9.30833 loss = 0.0110123372
# Epoch[20800/97886], predict data is -0.25992 -0.60309 5.38681, groud truth is -0.26354 -0.12500 5.39167 loss = 0.0762012973
# Epoch[21000/97886], predict data is -0.61392 0.51296 5.40548, groud truth is -0.62134 0.06250 5.36667 loss = 0.0681599081
# Epoch[21200/97886], predict data is -0.42218 0.01883 7.49781, groud truth is -0.41888 0.12500 7.47222 loss = 0.0039789211
# Epoch[21400/97886], predict data is -0.08963 -0.31164 6.90200, groud truth is -0.09076 -0.62500 6.95278 loss = 0.0335909128
# Epoch[21600/97886], predict data is -0.01980 -0.04703 9.73725, groud truth is -0.01047 -0.12500 9.73333 loss = 0.0020605882
# Epoch[21800/97886], predict data is -0.17544 -0.36588 11.04226, groud truth is -0.17628 -0.25000 11.04167 loss = 0.0044762315
# Epoch[22000/97886], predict data is -0.01403 0.06433 10.45688, groud truth is -0.01745 0.12500 10.45278 loss = 0.0012366381
# Epoch[22200/97886], predict data is -0.69513 -1.64852 10.17882, groud truth is -0.67893 -1.56250 10.17778 loss = 0.0025541491
# Epoch[22400/97886], predict data is -0.08820 -0.60612 10.82851, groud truth is -0.07156 0.18750 10.79444 loss = 0.2104255706
# Epoch[22600/97886], predict data is 1.03117 1.44156 8.14145, groud truth is 1.03149 1.56250 8.19167 loss = 0.0057161660
# Epoch[22800/97886], predict data is 1.36532 1.31570 9.24458, groud truth is 1.34216 2.06250 9.22500 loss = 0.1862076074
# Epoch[23000/97886], predict data is -0.26541 -1.06092 13.01427, groud truth is -0.26704 -1.18750 12.99167 loss = 0.0055119307
# Epoch[23200/97886], predict data is -0.80955 -1.79803 12.34908, groud truth is -0.78889 -1.43750 12.41667 loss = 0.0449931361
# Epoch[23400/97886], predict data is -0.08614 0.26807 12.29249, groud truth is -0.06283 -0.56250 12.28889 loss = 0.2301354557
# Epoch[23600/97886], predict data is -0.04538 -0.48722 14.41841, groud truth is -0.02967 0.00000 14.36111 loss = 0.0803036392
# Epoch[23800/97886], predict data is -0.16785 -1.01634 14.58123, groud truth is -0.16930 -1.12500 14.51667 loss = 0.0053262194
# Epoch[24000/97886], predict data is -0.40247 -1.45788 14.31026, groud truth is -0.41015 -1.06250 14.38056 loss = 0.0537756830
# Epoch[24200/97886], predict data is 0.00024 -0.91231 15.15079, groud truth is -0.05236 -0.06250 15.13611 loss = 0.2417174429
# Epoch[24400/97886], predict data is 0.42828 1.47006 15.43095, groud truth is 0.46251 1.75000 15.46111 loss = 0.0268162638
# Epoch[24600/97886], predict data is 0.37529 0.94345 16.26612, groud truth is 0.38397 1.25000 16.27222 loss = 0.0313619822
# Epoch[24800/97886], predict data is 0.21543 0.40118 15.36788, groud truth is 0.22515 0.62500 15.33056 loss = 0.0171937700
# Epoch[25000/97886], predict data is -0.12357 -1.17766 12.04647, groud truth is -0.12392 -1.00000 12.03889 loss = 0.0105402051
# Epoch[25200/97886], predict data is 0.08843 -0.21671 11.15343, groud truth is -0.01222 -0.18750 11.51389 loss = 0.0469713844
# Epoch[25400/97886], predict data is -0.05926 -0.06719 13.44804, groud truth is 0.09425 0.06250 13.31944 loss = 0.0189740490
# Epoch[25600/97886], predict data is 0.24215 0.51595 13.86508, groud truth is 0.26878 0.56250 13.85833 loss = 0.0009739795
# Epoch[25800/97886], predict data is 0.21418 0.40462 14.52361, groud truth is 0.21817 0.25000 14.51944 loss = 0.0079801613
# Epoch[26000/97886], predict data is 0.26726 0.84228 15.62321, groud truth is 0.23911 0.25000 15.27500 loss = 0.1576120108
# Epoch[26200/97886], predict data is 0.20539 0.06751 16.43591, groud truth is 0.20420 -0.06250 16.36111 loss = 0.0074999575
# Epoch[26400/97886], predict data is 0.07531 -0.48473 18.03738, groud truth is -0.03142 -0.37500 17.50000 loss = 0.1040695235
# Epoch[26600/97886], predict data is -0.20210 -0.66453 17.76488, groud truth is -0.24086 -1.18750 17.66389 loss = 0.0950674415
# Epoch[26800/97886], predict data is -0.14920 -0.38288 17.92477, groud truth is -0.17802 -0.56250 17.89722 loss = 0.0112844510
# Epoch[27000/97886], predict data is -0.04513 0.19634 18.21393, groud truth is -0.05061 0.31250 18.20555 loss = 0.0045309579
# Epoch[27200/97886], predict data is 0.01108 -0.25816 14.73955, groud truth is 0.00349 -0.06250 14.71944 loss = 0.0129147759
# Epoch[27400/97886], predict data is 0.01205 -0.82299 15.13190, groud truth is 0.01396 -0.62500 15.14167 loss = 0.0130994916
# Epoch[27600/97886], predict data is 0.18139 0.10701 15.38356, groud truth is 0.15184 0.00000 15.38333 loss = 0.0041080783
# Epoch[27800/97886], predict data is 0.20303 0.08626 16.03656, groud truth is 0.20420 0.31250 16.10000 loss = 0.0184041243
# Epoch[28000/97886], predict data is 0.15907 0.43097 14.65021, groud truth is 0.16930 0.25000 14.89167 loss = 0.0303856432
# Epoch[28200/97886], predict data is -0.04473 -1.30142 14.33870, groud truth is -0.04712 -1.06250 14.33056 loss = 0.0190508272
# Epoch[28400/97886], predict data is -0.07509 -0.26932 14.61072, groud truth is -0.07854 -0.37500 14.58889 loss = 0.0038856494
# Epoch[28600/97886], predict data is -0.48352 -1.47014 14.86017, groud truth is -0.48695 -1.62500 14.86389 loss = 0.0080025410
# Epoch[28800/97886], predict data is -0.48839 -1.83426 15.67738, groud truth is -0.48346 -1.62500 15.67222 loss = 0.0146139516
# Epoch[29000/97886], predict data is -0.48363 -1.21386 15.46366, groud truth is -0.47997 -1.25000 15.46667 loss = 0.0004427857
# Epoch[29200/97886], predict data is -0.45152 -1.70202 15.58330, groud truth is -0.45553 -1.56250 15.56667 loss = 0.0065862616
# Epoch[29400/97886], predict data is -0.49432 -1.08254 15.13872, groud truth is -0.49218 -1.25000 15.13333 loss = 0.0093590496
# Epoch[29600/97886], predict data is -0.28123 -0.77276 15.79065, groud truth is -0.27751 -0.37500 15.80556 loss = 0.0528169125
# Epoch[29800/97886], predict data is 0.00095 -0.18529 15.67859, groud truth is 0.00349 -0.12500 15.66111 loss = 0.0013155394
# Epoch[30000/97886], predict data is 0.10048 -0.63495 14.70114, groud truth is 0.13963 -0.75000 14.72500 loss = 0.0051127109
# Epoch[30200/97886], predict data is 0.05390 -1.06271 14.70302, groud truth is -0.03840 -1.12500 14.73611 loss = 0.0044978610
# Epoch[30400/97886], predict data is -0.00038 -0.69130 15.51012, groud truth is -0.02443 -0.43750 15.59722 loss = 0.0241934676
# Epoch[30600/97886], predict data is 0.07978 0.30084 15.38115, groud truth is 0.08552 0.18750 15.37222 loss = 0.0043195277
# Epoch[30800/97886], predict data is 0.09297 -0.04093 14.94530, groud truth is 0.06981 -0.50000 14.90833 loss = 0.0708832070
# Epoch[31000/97886], predict data is -0.02776 -0.96500 14.12459, groud truth is -0.02269 -1.06250 14.12500 loss = 0.0031775788
# Epoch[31200/97886], predict data is -0.02166 -0.32225 14.77495, groud truth is -0.01571 -0.18750 14.80000 loss = 0.0062733721
# Epoch[31400/97886], predict data is -0.01666 -0.27695 15.95121, groud truth is -0.00873 -0.62500 15.91667 loss = 0.0407986790
# Epoch[31600/97886], predict data is -0.01459 -0.52296 16.25783, groud truth is 0.00349 -0.56250 16.46111 loss = 0.0144044245
# Epoch[31800/97886], predict data is 0.02473 -0.64234 16.37468, groud truth is 0.03142 -0.37500 16.36111 loss = 0.0239003953
# Epoch[32000/97886], predict data is -0.02843 -0.70150 16.94490, groud truth is -0.03665 -0.37500 16.88056 loss = 0.0369378030
# Epoch[32200/97886], predict data is -0.03453 -0.86837 17.29496, groud truth is -0.04014 -0.81250 17.30000 loss = 0.0010592822
# Epoch[32400/97886], predict data is 0.07263 -0.41632 15.67406, groud truth is 0.07156 -0.43750 15.68056 loss = 0.0001639956
# Epoch[32600/97886], predict data is 0.23509 0.73631 16.17664, groud truth is 0.23911 0.75000 16.18056 loss = 0.0000729687
# Epoch[32800/97886], predict data is 0.26695 0.65685 17.17929, groud truth is 0.25133 0.25000 17.18333 loss = 0.0552628040
# Epoch[33000/97886], predict data is 0.01324 -0.89268 18.56874, groud truth is 0.01396 0.06250 18.43056 loss = 0.3104870021
# Epoch[33200/97886], predict data is 0.03380 -0.07454 17.88576, groud truth is 0.02094 0.00000 17.90833 loss = 0.0020767997
# Epoch[33400/97886], predict data is 0.04117 0.50624 18.06041, groud truth is 0.04538 0.50000 18.05556 loss = 0.0000267566
# Epoch[33600/97886], predict data is -0.04315 -0.22855 18.63911, groud truth is 0.00175 0.06250 18.62222 loss = 0.0290032923
# Epoch[33800/97886], predict data is -0.07680 -0.58076 18.17025, groud truth is -0.03491 -0.81250 18.24444 loss = 0.0203208458
# Epoch[34000/97886], predict data is 0.02704 -0.73925 18.20751, groud truth is 0.00000 -0.62500 18.13611 loss = 0.0062936754
# Epoch[34200/97886], predict data is 0.06443 0.25535 17.81595, groud truth is 0.06632 0.00000 17.85278 loss = 0.0221881289
# Epoch[34400/97886], predict data is 0.09845 0.70663 16.85575, groud truth is 0.09948 0.37500 16.86389 loss = 0.0366823636
# Epoch[34600/97886], predict data is 0.05330 -0.08751 16.49769, groud truth is 0.05411 -0.18750 16.49167 loss = 0.0033449056
# Epoch[34800/97886], predict data is -0.02960 -0.43259 16.24356, groud truth is -0.02618 -0.62500 16.25278 loss = 0.0123723978
# Epoch[35000/97886], predict data is 0.01287 0.05579 16.21304, groud truth is 0.01396 0.00000 16.20833 loss = 0.0010453427
# Epoch[35200/97886], predict data is -0.03908 -0.15362 16.47229, groud truth is -0.04014 -0.25000 16.46111 loss = 0.0031383233
# Epoch[35400/97886], predict data is -0.01137 0.03754 16.28970, groud truth is 0.00698 0.25000 16.26944 loss = 0.0152950138
# Epoch[35600/97886], predict data is -0.03019 -0.64206 16.81630, groud truth is -0.03142 -0.50000 16.80833 loss = 0.0067487485
# Epoch[35800/97886], predict data is -0.05670 -0.28411 16.55295, groud truth is 0.00349 -0.31250 16.56389 loss = 0.0015160491
# Epoch[36000/97886], predict data is 0.01210 0.02809 16.28997, groud truth is 0.02094 0.56250 16.28056 loss = 0.0952536166
# Epoch[36200/97886], predict data is -0.14067 -0.52030 15.32720, groud truth is -0.05061 0.18750 15.29444 loss = 0.1700525135

# %%
print("the order of ouput data is angle, torque, speed")

# %% [markdown]
# ## 5 seconds

# %%
rnn_5=rnnModel(3,10,3,2)
criterion_5=nn.MSELoss()
optimizer_5=optim.Adam(rnn_5.parameters(),lr=1e-2)
sec = 200
initial_data = torch.from_numpy(train_data[0].astype(np.float32)).reshape(1,1,3)
for e in range(0, len(train_data)) :
    inputs = Variable(initial_data)
    target = Variable(torch.from_numpy(train_label[e].astype(np.float32)).reshape(1,1,3))
    # forward
    output = rnn_5(inputs)
    loss = criterion_5(output, target)
    # update gradients
    optimizer_5.zero_grad()
    loss.backward()
    optimizer_5.step()
    # print training information
    print_loss = loss.item()
    if e % sec == 0 :
        
        print('Epoch[{}/{}], predict data is {:.5f} {:.5f} {:.5f}, groud truth is {:.5f} {:.5f} {:.5f} loss = {:.10f}'.format(e,len(train_data),output.detach().numpy()[0,0,0],output.detach().numpy()[0,0,1],output.detach().numpy()[0,0,2],train_label[e,0],train_label[e,1],train_label[e,2], print_loss))
    if e % 250 ==0 :
        initial_data = torch.from_numpy(train_data[e].astype(np.float32)).reshape(1,1,3)
        print('5 seconds\n')
    else:    
        initial_data = output

# %% [markdown]
# ## 10 seconds

# %%
rnn_10=rnnModel(3,10,3,2)
criterion_10=nn.MSELoss()
optimizer_10=optim.Adam(rnn_10.parameters(),lr=1e-2)
sec = 200
initial_data = torch.from_numpy(train_data[0].astype(np.float32)).reshape(1,1,3)
for e in range(0, len(train_data)) :
    inputs = Variable(initial_data)
    target = Variable(torch.from_numpy(train_label[e].astype(np.float32)).reshape(1,1,3))
    # forward
    output = rnn_10(inputs)
    loss = criterion_10(output, target)
    # update gradients
    optimizer_10.zero_grad()
    loss.backward()
    optimizer_10.step()
    # print training information
    print_loss = loss.item()
    if e % sec == 0 :
        
        print('Epoch[{}/{}], predict data is {:.5f} {:.5f} {:.5f}, groud truth is {:.5f} {:.5f} {:.5f} loss = {:.10f}'.format(e,len(train_data),output.detach().numpy()[0,0,0],output.detach().numpy()[0,0,1],output.detach().numpy()[0,0,2],train_label[e,0],train_label[e,1],train_label[e,2], print_loss))
    if e % 500 ==0 :
        initial_data = torch.from_numpy(train_data[e].astype(np.float32)).reshape(1,1,3)
        print('10 seconds\n')
    else:    
        initial_data = output
